# %%
print ("hello")
# Out:
# hello

# %%
list=[1,2,3]
print(list[-1:])
dict={'a':'2','b':2}
print(dict[a])
# Out:
#   File "<ipython-input-27-4cad7916c53a>", line 4
#     print(dict{a})
#               ^
# SyntaxError: invalid syntax
