# %%
import pandas as pd
import datetime
import numpy as np
# df1 = pd.read_excel(file)
# df = pd.read_excel(excel_link, sheet_name, dtype=str)

# %%
import pandas as pd

# Read the file and specify which column is the date
customer_calls = pd.read_excel("sheet4.xlsx")

# # Output with dates converted to YYYY-MM-DD
# customer_calls["Date of production"] = pd.to_datetime(customer_calls["Date of production"]).dt.strftime("%d-%m-%Y")
# customer_calls.to_excel("sheet4_DD_YYYY_MM_.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-446ae5361e16> in <module>
#       2
#       3 # Read the file and specify which column is the date
# ----> 4 customer_calls = pd.read_excel("sheet4.xlsx")
#       5
#       6 # # Output with dates converted to YYYY-MM-DD
#
# c:\users\amc\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
# !pip install xlrd
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\amc\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# Read the file and specify which column is the date
customer_calls = pd.read_excel("sheet4.xlsx")

# # Output with dates converted to YYYY-MM-DD
# customer_calls["Date of production"] = pd.to_datetime(customer_calls["Date of production"]).dt.strftime("%d-%m-%Y")
# customer_calls.to_excel("sheet4_DD_YYYY_MM_.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-446ae5361e16> in <module>
#       2
#       3 # Read the file and specify which column is the date
# ----> 4 customer_calls = pd.read_excel("sheet4.xlsx")
#       5
#       6 # # Output with dates converted to YYYY-MM-DD
#
# c:\users\amc\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
# !pip install openpyxl
# Out:
# ...
# Using legacy 'setup.py install' for et-xmlfile, since package 'wheel' is not installed.
# ...
#     Running setup.py install for et-xmlfile: started
#     Running setup.py install for et-xmlfile: finished with status 'done'
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\amc\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# Read the file and specify which column is the date
customer_calls = pd.read_excel("sheet4.xlsx")

# Output with dates converted to YYYY-MM-DD
customer_calls["Date of production"] = pd.to_datetime(customer_calls["Date of production"]).dt.strftime("%m.%d.%Y")
customer_calls.to_excel("sheet4_new_DD_MM_YYYY.xlsx")

# %%
customer_calls.head()
# Out:
#    S.No                          Name of the unit          Location  \
# 0     1    M/s M.Altaf Bhat, Trajbal Charisharief  Jammu & Kashmir
# 1     2  M/s M. Maqbool Dar, Trajbal Charisharief  Jammu & Kashmir
# 2     3  M/s Assadullah Bhat Trajbal Charisharief  Jammu & Kashmir
# 3     4   M/s Gh Mohd Bhat , Trajbal Charisharief  Jammu & Kashmir
# 4     5        M/s Gh Mohammad Shah, Charisharief  Jammu & Kashmir
#
#                     Product                     Sector Date of production  \
# 0  Handicraft articles cane    Handloom and Handicraft         20.05.1996
# 1  Handicraft articles cane    Handloom and Handicraft         02.02.1995
# 2  Handicraft articles cane    Handloom and Handicraft         04.02.1996
# 3  Handicraft articles cane    Handloom and Handicraft         25.03.1995
# 4              Willow works  Wood & Related Activities         01.06.1993
#
#   Investment(in lakhs)  Employment (Classification) Micro/Small/Medium  \
# ...
